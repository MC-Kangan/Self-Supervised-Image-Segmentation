# %%
# Import the necessary libraries
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
# Import torch vision
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader
# Import resnet50 model from torchvision
from torchvision.models import resnet50
from torch.optim.optimizer import Optimizer, required
import re

# %%
# import a simple dataset for testing model architecture
# import the cifar10 dataset

# %% [markdown]
# # Data augmentation

# %%
# configure the image height and width for resizing the images to input the model
# As the pytorch resnet model requires the input image to be 224x224 ,even with pre-trained weights equal False
# we will resize the images to 224x224, as size bigger than 224x224 will be cropped to 224x224
image_height = 224
image_width = 224

def get_color_distortion(s=1.0):
    # s is the strength of color distortion.
    color_jitter = transforms.ColorJitter(0.8*s, 0.8*s, 0.8*s, 0.2*s)
    rnd_color_jitter = transforms.RandomApply([color_jitter], p=0.8)
    rnd_gray = transforms.RandomGrayscale(p=0.2)
    color_distort = transforms.Compose([
    rnd_color_jitter,
    rnd_gray])
    return color_distort
# This is the best combination of data augmentation techniques for the SimCLR model shown in the paper
data_transforms = transforms.Compose([
    transforms.ToPILImage(),  # Convert tensor to PIL Image
    transforms.RandomResizedCrop((image_height, image_width)), # This follow the random cropping and resizing in the paper
    get_color_distortion(s=1),
    transforms.GaussianBlur(kernel_size=23, sigma=(0.1, 2.0)), # In the paper, the kernel size is 10% of the image height and width and sigma is between 0.1 and 2.0. As the kernel size must be odd, we choose 23 as the kernel size.
    transforms.ToTensor()
])

# %% [markdown]
# # Define the loss function for SimCLR

# %%
def nt_xent_loss(queries, keys, temperature = 0.1):
    b, device = queries.shape[0], queries.device

    n = b * 2  # 同一图片内部不同patch也是负样本
    projs = torch.cat((queries, keys))
    logits = projs @ projs.t()

    mask = torch.eye(n, device=device).bool()
    logits = logits[~mask].reshape(n, n - 1)  # 同一图片内部不同patch也是负样本，除了自己和自己
    logits /= temperature

    labels = torch.cat(((torch.arange(b, device = device) + b - 1), torch.arange(b, device=device)), dim=0)
    loss = F.cross_entropy(logits, labels, reduction = 'sum')
    loss /= n
    return loss

# %% [markdown]
# # Get the backbone model f(.) to train on the data augmentation dataset.

# %%
# Load the resnet50 model which returns the features before the classification layer
model = resnet50(pretrained=False) # Optionally, you can set pretrained=True to use the pre-trained weights
# return the features before the classification layer
model.fc = nn.Identity() # Remove the classification layer
# Print the model architecture
# print(model)
# get the output shape of the model by passing a random tensor of the image size
# print(model(torch.randn(1, 3, image_height, image_width)).shape)




# Define the model
class SimCLR(nn.Module):
    def __init__(self, model, temperature=0.1):
        super(SimCLR, self).__init__()
        # get the device of the model
        self.model = model
        # This is the two-layer MLP projection head as described in the paper whcih represents the g(.) function
        self.projection_head = nn.Sequential(
            nn.Linear(2048, 512),
            nn.ReLU(),
            nn.Linear(512, 128)
        )
        self.temperature = temperature
        # Define the cosine similarity function
        # cosine_similarity = lambda z_i, z_j: torch.dot(z_i, z_j) / (torch.norm(z_i) * torch.norm(z_j))
    def forward(self, x_i, x_j):
        h_i = self.model(x_i)
        h_j = self.model(x_j)
        # print(h.shape)
        z_i = self.projection_head(h_i)
        # print(z_i.shape)
        z_j = self.projection_head(h_j)
        # get the normalized projection head output
        # z_i = nn.functional.normalize(z_i, dim=1)
        # z_j = nn.functional.normalize(z_j, dim=1)

        # Loss calculation by nt_xent_loss function
        loss = nt_xent_loss(z_i, z_j, self.temperature)
        return loss
# Create the SimCLR model
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
# define the Lars optimizer from scratch
# As the the coursework limit to use of 4 external libraries, we will implement the LARS optimizer from scratch

from torch.optim.optimizer import Optimizer, required
import re

EETA_DEFAULT = 0.001


class LARS(Optimizer):
    """
    Layer-wise Adaptive Rate Scaling for large batch training.
    Introduced by "Large Batch Training of Convolutional Networks" by Y. You,
    I. Gitman, and B. Ginsburg. (https://arxiv.org/abs/1708.03888)
    """

    def __init__(
        self,
        params,
        lr=required,
        momentum=0.9,
        use_nesterov=False,
        weight_decay=0.0,
        exclude_from_weight_decay=None,
        exclude_from_layer_adaptation=None,
        classic_momentum=True,
        eeta=EETA_DEFAULT,
    ):
        """Constructs a LARSOptimizer.
        Args:
        lr: A `float` for learning rate.
        momentum: A `float` for momentum.
        use_nesterov: A 'Boolean' for whether to use nesterov momentum.
        weight_decay: A `float` for weight decay.
        exclude_from_weight_decay: A list of `string` for variable screening, if
            any of the string appears in a variable's name, the variable will be
            excluded for computing weight decay. For example, one could specify
            the list like ['batch_normalization', 'bias'] to exclude BN and bias
            from weight decay.
        exclude_from_layer_adaptation: Similar to exclude_from_weight_decay, but
            for layer adaptation. If it is None, it will be defaulted the same as
            exclude_from_weight_decay.
        classic_momentum: A `boolean` for whether to use classic (or popular)
            momentum. The learning rate is applied during momeuntum update in
            classic momentum, but after momentum for popular momentum.
        eeta: A `float` for scaling of learning rate when computing trust ratio.
        name: The name for the scope.
        """

        self.epoch = 0
        defaults = dict(
            lr=lr,
            momentum=momentum,
            use_nesterov=use_nesterov,
            weight_decay=weight_decay,
            exclude_from_weight_decay=exclude_from_weight_decay,
            exclude_from_layer_adaptation=exclude_from_layer_adaptation,
            classic_momentum=classic_momentum,
            eeta=eeta,
        )

        super(LARS, self).__init__(params, defaults)
        self.lr = lr
        self.momentum = momentum
        self.weight_decay = weight_decay
        self.use_nesterov = use_nesterov
        self.classic_momentum = classic_momentum
        self.eeta = eeta
        self.exclude_from_weight_decay = exclude_from_weight_decay
        # exclude_from_layer_adaptation is set to exclude_from_weight_decay if the
        # arg is None.
        if exclude_from_layer_adaptation:
            self.exclude_from_layer_adaptation = exclude_from_layer_adaptation
        else:
            self.exclude_from_layer_adaptation = exclude_from_weight_decay

    def step(self, epoch=None, closure=None):
        loss = None
        if closure is not None:
            loss = closure()

        if epoch is None:
            epoch = self.epoch
            self.epoch += 1

        for group in self.param_groups:
            weight_decay = group["weight_decay"]
            momentum = group["momentum"]
            eeta = group["eeta"]
            lr = group["lr"]

            for p in group["params"]:
                if p.grad is None:
                    continue

                param = p.data
                grad = p.grad.data

                param_state = self.state[p]

                # TODO: get param names
                # if self._use_weight_decay(param_name):
                grad += self.weight_decay * param

                if self.classic_momentum:
                    trust_ratio = 1.0

                    # TODO: get param names
                    # if self._do_layer_adaptation(param_name):
                    w_norm = torch.norm(param)
                    g_norm = torch.norm(grad)

                    # device = g_norm.get_device()
                    device = g_norm.device
                    trust_ratio = torch.where(
                        w_norm.gt(0),
                        torch.where(
                            g_norm.gt(0),
                            (self.eeta * w_norm / g_norm),
                            torch.Tensor([1.0]).to(device),
                        ),
                        torch.Tensor([1.0]).to(device),
                    ).item()

                    scaled_lr = lr * trust_ratio
                    if "momentum_buffer" not in param_state:
                        next_v = param_state["momentum_buffer"] = torch.zeros_like(
                            p.data
                        )
                    else:
                        next_v = param_state["momentum_buffer"]

                    next_v.mul_(momentum).add_(scaled_lr, grad)
                    if self.use_nesterov:
                        update = (self.momentum * next_v) + (scaled_lr * grad)
                    else:
                        update = next_v

                    p.data.add_(-update)
                else:
                    raise NotImplementedError

        return loss

    def _use_weight_decay(self, param_name):
        """Whether to use L2 weight decay for `param_name`."""
        if not self.weight_decay:
            return False
        if self.exclude_from_weight_decay:
            for r in self.exclude_from_weight_decay:
                if re.search(r, param_name) is not None:
                    return False
        return True

    def _do_layer_adaptation(self, param_name):
        """Whether to do layer-wise learning rate adaptation for `param_name`."""
        if self.exclude_from_layer_adaptation:
            for r in self.exclude_from_layer_adaptation:
                if re.search(r, param_name) is not None:
                    return False
        return True

# %% [markdown]
# # Start training the model

# %%
# Start the training loop for SimCLR
model = resnet50(pretrained=False)
model.fc = nn.Identity()
simclr_model = SimCLR(model)
# Hyperparameters
batch_size = 200
learning_rate = 0.2
num_epochs = 10

# Simple transform for the original CIFAR-10 dataset and resize the images to 224x224
transform = transforms.Compose([
    transforms.Resize((image_height, image_width)),
    transforms.ToTensor()
])
# define the dataset with and without data augmentation and with
train_dataset = datasets.CIFAR10(root='dataset/', train=True, transform=transform, download=True)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# Check if GPU is available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# move the model to the device
model = model.to(device)  # this is the model you want to save for pre-training, where f(.) is the ResNet-50
simclr_model = simclr_model.to(device)

# Define the optimizer
optimizer = LARS(
    [params for params in model.parameters() if params.requires_grad],
    lr=0.2,
    weight_decay=1e-6,
    exclude_from_weight_decay=["batch_normalization", "bias"],
)

# Start the training loop for SimCLR
for epoch in range(num_epochs):
    for data in train_loader:
        images_i, _ = data
        images_i = images_i.to(device)
        # apply the data augmentation techniques to the images
        # images_j = data_transforms(data[0])
        images_j = torch.stack([data_transforms(image) for image in data[0]])
        images_j = images_j.to(device)
        # Perform the forward pass
        loss = simclr_model(images_i, images_j)
        # Perform the backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        print(loss)
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item()}')

# Save the model
torch.save(model.state_dict(), 'simclr_backbone.ckpt')
torch.save(simclr_model.state_dict(), 'simclr_model.ckpt')
# Out:
# Files already downloaded and verified
# <ipython-input-6-748ce338ff25>:133: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:1630.)
#   next_v.mul_(momentum).add_(scaled_lr, grad)
# tensor(257.9359, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(41.1608, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(16.5748, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(11.6405, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(9.9549, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(10.5312, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.5732, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(9.8641, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(10.0717, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(9.5765, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(12.6961, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(14.0790, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(16.1308, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(12.2675, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(12.4464, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(11.6427, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(10.0633, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(12.6839, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(13.9253, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(11.5226, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(15.3808, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(12.5321, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(11.4239, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(11.4369, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(13.1504, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(12.4390, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(13.6810, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(12.0181, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(10.3784, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(13.0875, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(12.7467, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(10.7093, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(12.4365, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(11.6220, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(10.3683, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(9.9555, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(10.1242, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(10.4892, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(15.1368, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(11.8194, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(12.4303, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(11.5296, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(11.4999, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(11.2865, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(11.4970, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(12.0468, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(10.5329, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(11.3750, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(10.9774, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(11.4805, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(12.3465, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(10.0529, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(9.4573, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(10.1499, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(11.4050, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(9.9465, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(10.0544, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(9.2991, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(10.9089, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(10.2486, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(9.7513, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(9.5142, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(9.7899, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.7519, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(11.5690, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(11.0422, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(10.1813, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(10.3406, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(9.1823, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.8475, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(9.0897, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.8785, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.8175, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.5739, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(9.1331, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(9.0303, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.9194, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.5839, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.0693, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.5160, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(10.0113, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.2001, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(9.3979, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(9.0737, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.8805, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.6785, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(9.1462, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(9.1035, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.6249, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(9.1597, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(9.0511, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.4709, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(10.5441, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.7200, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.4600, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.6542, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(13.4396, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(12.5063, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(9.1551, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(9.9173, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(9.1134, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(9.5936, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(9.3214, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(9.0922, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.9097, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.9113, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.8782, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.1296, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.9446, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.2713, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.5934, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.7688, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.1324, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(9.1472, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(9.7979, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.1403, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.3954, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.8728, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.7616, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.6843, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.6431, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.1599, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.7014, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.8507, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.8544, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.9508, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.1853, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.1538, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.5041, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.3422, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.4789, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.3332, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(11.6977, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(9.1415, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.7104, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.1735, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(9.1278, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.4386, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.8235, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.3342, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.7599, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.6090, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.9876, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.5156, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.0965, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.5643, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.1449, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.2533, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.4925, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.2978, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.5798, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.2850, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.8203, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.3305, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.8815, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.2080, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.4008, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.7560, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.7619, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.7190, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.3937, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.5197, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.4581, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.9279, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.2759, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.4925, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.1010, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.1430, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.0355, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.8566, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.1519, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.0984, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(8.0014, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.9405, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.6224, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.8283, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.2038, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.2659, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.6753, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.3588, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.0397, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.4734, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.7860, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.0222, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.7033, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.5809, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.2185, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.3462, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.2328, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.1013, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.1772, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.6713, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.4385, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.5104, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.5110, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.0752, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.7523, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.9742, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.7233, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.3103, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.6062, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.5676, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.7132, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.6179, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.6978, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.8643, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.4610, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.8893, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.9133, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(7.3219, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.4416, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.2246, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.3689, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.2138, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.3279, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.2705, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.8424, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.8149, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.7809, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.0344, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.1316, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.0598, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.6387, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.7560, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.8738, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.7107, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.8055, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.9032, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.7688, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.0703, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.7577, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.4303, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.9573, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.7294, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.6039, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.5950, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.6131, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.8706, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.5234, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.1905, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.0862, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.2508, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.6762, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.5459, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.8019, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.8220, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.8833, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.6480, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.7118, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.3349, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch [1/10], Loss: 5.334896564483643
# tensor(5.9440, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.4998, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.4622, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.5976, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.0874, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.9697, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.1190, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(6.0995, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.8721, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.6619, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.4608, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.7145, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.3413, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.1535, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.3997, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.3199, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.4612, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.4121, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.4469, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.1844, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.4714, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.3582, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.5082, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.4899, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.0333, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.2714, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.1736, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.9920, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.4058, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.2786, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.0914, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.1299, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.3432, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.2321, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.1920, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.1030, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.1734, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.2181, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.1007, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.0759, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.0544, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.2173, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.1372, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.9022, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.1555, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.9739, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.4724, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.1456, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.5596, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.9512, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.2566, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.2105, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.0994, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.4228, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.0655, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.2688, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.3634, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.1313, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.3020, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.1702, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.0064, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.0583, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.7715, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.9640, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.8640, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.9215, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.9051, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.1276, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.6916, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.0485, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.1277, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.0186, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.0001, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.9062, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.7259, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.8214, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.6825, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.9949, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.9419, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.7817, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.7696, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.6222, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.7639, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.7337, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.7551, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.7912, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.7192, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.7173, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.6093, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.8628, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.6538, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.8062, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.7074, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.9251, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.5889, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.5680, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.7562, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.4375, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.7802, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.4877, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.4841, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.4621, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.4219, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.6258, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.4858, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.1678, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.5773, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.6552, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.4582, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.4148, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.6121, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.7439, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.3178, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.2372, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.2538, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.4862, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.2930, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.4752, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.1392, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.3485, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.5413, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.3247, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.1583, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.5299, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.2939, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.6703, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.2167, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.3480, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.1121, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.1866, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.2177, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.2977, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.1916, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.2857, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.0383, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.1862, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.9468, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.1698, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.2924, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.2760, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.1972, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.2548, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.0881, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.4540, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.9971, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.2749, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.0231, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.9484, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.2547, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.0325, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.9880, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.1491, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.1996, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.9939, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.9932, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.9827, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.8878, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.8375, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.8135, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.8463, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.3008, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.8772, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.2451, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.9194, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.9276, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.1314, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.2136, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.8957, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.0301, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.5921, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.0663, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.8622, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.7327, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.5587, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.8033, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.8664, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.8927, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.8083, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.9199, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.8962, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.9680, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.8931, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.8023, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.8639, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.7368, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.6062, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.7539, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.7808, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.4414, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.0203, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.5533, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.5891, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.8802, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.5814, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.6277, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.6664, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.8710, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.6668, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.7658, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.7052, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.0286, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.9513, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.6509, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.8698, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.6722, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.5256, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.5048, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.6527, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.5609, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.4497, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.6511, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.5880, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.5953, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.7162, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.6251, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.7131, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.5025, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.6630, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.5813, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.5455, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.5572, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.6671, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1311, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.3171, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.4630, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.3632, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.5337, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.4010, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0795, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.3463, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.4854, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1563, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.6499, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1380, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1585, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.2825, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.6001, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.3981, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1730, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.3248, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7334, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.2280, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1411, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9618, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.2597, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.5272, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1195, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.2524, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.2228, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.2896, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch [2/10], Loss: 3.2896339893341064
# tensor(3.2592, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.5801, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.6095, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.3646, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.2195, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.5130, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.3559, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8589, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.6263, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9405, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0518, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9156, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.2266, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.3103, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0983, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.4347, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.2158, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.4619, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1327, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1158, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1435, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0667, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9735, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0501, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1283, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1334, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0312, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1977, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9116, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.2731, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0045, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.2349, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1707, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0247, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8935, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.3177, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.2531, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9388, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8034, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0983, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.2028, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0547, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1577, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0168, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.2464, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9759, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1226, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0734, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8845, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1758, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0628, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1427, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8933, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1755, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6022, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7605, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9194, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4488, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7627, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0193, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0563, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8643, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.2259, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0298, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8810, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0058, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7833, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7886, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7392, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8456, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8878, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9544, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0956, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0887, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1017, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9099, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7935, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0527, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9527, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7894, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0773, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8723, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9714, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9087, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5907, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8218, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9134, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0048, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1081, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4732, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6526, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6491, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7185, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7759, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8506, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0903, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0687, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8295, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7686, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7431, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6795, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7584, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5916, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6003, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6718, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6643, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7144, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9667, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7601, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8864, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8491, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9934, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5546, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5214, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6434, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6885, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7231, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8121, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7748, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5813, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0985, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5320, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6600, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8099, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6923, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6280, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5747, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8510, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3246, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6004, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0168, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9281, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6762, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7530, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6391, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6584, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4736, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3700, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9480, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8161, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6443, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6082, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6603, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5558, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7063, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7675, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3716, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3788, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9220, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5895, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8050, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5847, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4282, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5762, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9672, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6430, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4327, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8260, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4273, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2807, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5958, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4908, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1650, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8837, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5761, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8245, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9170, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8790, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5618, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7224, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4527, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4186, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2431, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5248, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4781, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4907, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7164, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4343, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5266, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5464, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5896, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6088, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5190, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3849, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6580, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4550, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4653, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3247, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6067, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3557, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1930, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7072, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5905, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3863, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4814, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4581, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5362, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6642, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1607, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1624, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2646, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6906, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5212, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.0675, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2472, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6478, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7732, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3268, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4049, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5413, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4102, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3928, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7004, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6155, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3839, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7362, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5602, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4257, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7139, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.6513, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3618, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2503, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4795, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.0949, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.0970, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1918, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1757, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2465, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.0472, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6173, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3646, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2151, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2188, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2885, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3028, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1524, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5693, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5798, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4431, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2993, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3343, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3047, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4500, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3198, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3578, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2010, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.9455, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5458, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4040, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3625, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch [3/10], Loss: 2.362473487854004
# tensor(2.3124, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7561, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1792, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3812, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3208, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.0553, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.0870, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5222, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4904, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3351, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2119, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2184, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3195, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3917, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3248, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7174, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4577, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2706, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1589, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4219, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2583, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2030, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1961, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2000, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1857, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2799, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1167, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1469, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4876, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2638, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1678, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3973, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3838, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1741, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.9598, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3785, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1610, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2511, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2081, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1702, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3728, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1059, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1208, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.8356, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1898, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4536, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2514, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3295, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2987, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4245, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.0702, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.9248, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1028, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1289, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.9863, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.0488, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1182, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.0347, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1333, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.0282, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4269, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4343, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1871, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2716, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3655, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.0983, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.8411, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.9635, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.9517, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.9354, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.0769, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1085, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.0215, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1344, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2185, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2368, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.0730, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.9610, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.0818, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3349, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1777, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2078, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1815, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5539, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1982, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4779, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1172, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.8856, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2772, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.8889, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1024, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.9190, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.0434, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.9591, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2036, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2031, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3972, device='cuda:0', grad_fn=<DivBackward0>)
# ...
# tensor(1.1530, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8611, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7090, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8519, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5801, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6587, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7368, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9465, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8609, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8555, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9501, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8519, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8039, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8299, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7590, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6532, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0049, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7758, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9244, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8345, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7612, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8629, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8251, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9692, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8044, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8125, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1328, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8627, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7467, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9331, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8094, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7126, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9240, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8156, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch [9/10], Loss: 0.8156490921974182
# tensor(0.7746, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6668, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7797, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0192, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6521, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9715, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7386, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7854, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7410, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7248, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8214, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8332, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6679, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7168, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7250, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8096, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8589, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6781, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0215, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9532, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8358, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9591, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8417, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7382, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7142, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8654, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9165, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7303, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9802, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7841, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8241, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0060, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0227, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8900, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6372, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6132, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8963, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5456, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8796, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7230, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7508, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8171, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7830, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8398, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7605, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5816, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9444, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7707, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9723, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7673, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8085, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9399, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9779, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8807, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7662, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7769, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7336, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8789, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7099, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8201, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6997, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7821, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6013, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8317, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8803, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5696, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8458, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0703, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8949, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6161, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0645, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6921, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8718, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7613, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5505, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8700, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8305, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6101, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7518, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6748, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7256, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8436, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8498, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6524, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6323, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7036, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8162, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7741, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6957, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8011, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6599, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6675, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8194, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8465, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7762, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6892, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8254, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8195, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7070, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9461, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7247, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9145, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6810, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7487, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8103, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5377, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7906, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6677, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7057, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7863, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7189, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7995, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8116, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9316, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7266, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6311, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8382, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7430, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6151, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8621, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7405, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7395, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8580, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8168, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7970, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7174, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7258, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6765, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7529, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9754, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7062, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7981, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9030, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8029, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8211, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5786, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7001, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6925, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6137, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0291, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6382, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9363, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7795, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6389, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6830, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6947, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8579, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7152, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9443, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0079, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4906, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7326, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8011, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7459, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6003, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6169, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7773, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5764, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5512, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7510, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7296, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6286, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5859, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7703, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5718, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7587, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7702, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5823, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6898, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7322, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6304, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8091, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7900, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5244, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5957, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9647, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9964, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7835, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7614, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5208, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7754, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9174, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7129, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6867, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8649, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7239, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8415, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7172, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7833, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6629, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6603, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1033, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7552, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7051, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8097, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7403, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7356, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8189, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7368, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8928, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9680, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5077, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6750, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7630, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7122, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7679, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7379, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7036, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6603, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7364, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6331, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8737, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6603, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9299, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7850, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5288, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6997, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6276, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8328, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6554, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7802, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7647, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5400, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7768, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7100, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6835, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8933, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6482, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8540, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6564, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7959, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8202, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7966, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9489, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6464, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7235, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6433, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9243, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7802, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7143, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7223, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6404, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7806, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5172, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6121, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7652, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6826, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8186, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7614, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5337, device='cuda:0', grad_fn=<DivBackward0>)
# Epoch [10/10], Loss: 0.5337345600128174
